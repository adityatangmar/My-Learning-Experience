# %%
# Library yang sering digunakan
import os, shutil
import zipfile
import random
from random import sample
import shutil
from shutil import copyfile
import pathlib
from pathlib import Path
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm as tq
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Libraries untuk pemrosesan data gambar
import cv2
from PIL import Image
import skimage
from skimage import io
from skimage.transform import resize
from skimage.transform import rotate, AffineTransform, warp
from skimage import img_as_ubyte
from skimage.exposure import adjust_gamma
from skimage.util import random_noise

# %%
# Libraries untuk pembangunan model
import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras import Model, layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.layers import InputLayer, Conv2D, SeparableConv2D, MaxPooling2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Mencetak versi TensorFlow yang sedang digunakan
print(tf.__version__)
# Out:
# 2.20.0

# %%
# Mengatur token API Kaggle untuk mengakses dataset

import os
os.environ['KAGGLE_API_TOKEN'] = 'KGAT_ee3ec58a8b31b5f8bb0a046b0bc21d07'

# %%
import os
import shutil

# %%
# Download kaggle dataset and unzip the file
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d tolgadincer/labeled-chest-xray-images
# !unzip labeled-chest-xray-images.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tolgadincer/labeled-chest-xray-images
# License(s): other
# labeled-chest-xray-images.zip: Skipping, found more recently modified local copy (use --force to force download)
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import zipfile

with zipfile.ZipFile("labeled-chest-xray-images.zip", 'r') as zip_ref:
    zip_ref.extractall("dataset")

# %%
train_dir = "dataset/chest_xray/train"
test_dir = "dataset/chest_xray/test"

# Direktori baru untuk dataset gabungan
combined_dir = "chest_xray/dataset"

# %%
# Buat direktori baru untuk dataset gabungan
os.makedirs(combined_dir, exist_ok=True)

# %%
# Salin file dan folder dari train
for category in os.listdir(train_dir):
    category_dir = os.path.join(train_dir, category)
    if os.path.isdir(category_dir):
        shutil.copytree(category_dir, os.path.join(combined_dir, category), dirs_exist_ok=True)

# Salin file dan folder dari test
for category in os.listdir(test_dir):
    category_dir = os.path.join(test_dir, category)
    if os.path.isdir(category_dir):
        shutil.copytree(category_dir, os.path.join(combined_dir, category), dirs_exist_ok=True)

# %%
# Membuat kamus yang menyimpan gambar untuk setiap kelas dalam data
lung_image = {}

# Tentukan path sumber train
path = "chest_xray/"
path_sub = os.path.join(path, "dataset")
for i in os.listdir(path_sub):
    lung_image[i] = os.listdir(os.path.join(path_sub, i))

# Menampilkan secara acak 5 gambar di bawah setiap dari 2 kelas dari data.
# Anda akan melihat gambar yang berbeda setiap kali kode ini dijalankan.
path_sub = "chest_xray/dataset/"

# Menampilkan secara acak 5 gambar di bawah setiap kelas dari data latih
fig, axs = plt.subplots(len(lung_image.keys()), 5, figsize=(15, 15))

for i, class_name in enumerate(os.listdir(path_sub)):
    images = np.random.choice(lung_image[class_name], 5, replace=False)

    for j, image_name in enumerate(images):
        img_path = os.path.join(path_sub, class_name, image_name)
        img = Image.open(img_path).convert("L") # Konversi menjadi skala keabuan
        axs[i, j].imshow(img, cmap='gray')
        axs[i, j].set(xlabel=class_name, xticks=[], yticks=[])


fig.tight_layout()

# %%
# Definisikan path sumber
lung_path = "chest_xray/dataset/"

# Buat daftar yang menyimpan data untuk setiap nama file, path file, dan label dalam data
file_name = []
labels = []
full_path = []

# Dapatkan nama file gambar, path file, dan label satu per satu dengan looping, dan simpan sebagai dataframe
for path, subdirs, files in os.walk(lung_path):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)

distribution_train = pd.DataFrame({"path":full_path, 'file_name':file_name, "labels":labels})

# Plot distribusi gambar di setiap kelas
Label = distribution_train['labels']
plt.figure(figsize = (6,6))
sns.set_style("darkgrid")
plot_data = sns.countplot(Label)

# %%
# Membuat fungsi untuk melakukan rotasi berlawanan arah jarum jam
def anticlockwise_rotation(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    sudut = random.randint(0,180)
    return rotate(img, sudut)

# Membuat fungsi untuk melakukan rotasi searah jarum jam
def clockwise_rotation(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    sudut = random.randint(0,180)
    return rotate(img, -sudut)

# Membuat fungsi untuk membalik gambar secara vertikal dari atas ke bawah
def flip_up_down(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    return np.flipud(img)

# Membuat fungsi untuk memberikan efek peningkatan kecerahan pada gambar
def add_brightness(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    img = adjust_gamma(img, gamma=0.5,gain=1)
    return img

# Membuat fungsi untuk memberikan efek blur pada gambar
def blur_image(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    return cv2.GaussianBlur(img, (9,9),0)

# Membuat fungsi untuk memberikan efek pergeseran acak pada gambar
def sheared(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    transform = AffineTransform(shear=0.2)
    shear_image = warp(img, transform, mode="wrap")
    return shear_image

# Membuat fungsi untuk melakukan pergeseran melengkung pada gambar
def warp_shift(img):
    img = cv2.cvtColor(img, 0)
    img = cv2.resize(img, (224,224))
    transform = AffineTransform(translation=(0,40))
    warp_image = warp(img, transform, mode="wrap")
    return warp_image

# %%
# Membuat variabel transformasi yang akan menyimpan semua proses pra-pemrosesan
transformations = {
    'rotate anticlockwise': anticlockwise_rotation,
    'rotate clockwise': clockwise_rotation,
    'warp shift': warp_shift,
    'blurring image': blur_image,
    'add brightness': add_brightness,
    'flip up down': flip_up_down,
    'shear image': sheared
}

images_path = "chest_xray/dataset/NORMAL"
augmented_path = "chest_xray/dataset/NORMAL_augmented"

images = []

# Membaca nama gambar
for im in os.listdir(images_path):
    images.append(os.path.join(images_path, im))

images_to_generate = 2000
i = 1

while i <= images_to_generate:
    image = random.choice(images)

    try:
        original_image = io.imread(image)
        transformed_image = None

        n = 0
        transformation_count = random.randint(1, len(transformations))

        while n <= transformation_count:
            key = random.choice(list(transformations))
            transformed_image = transformations[key](original_image)
            n += 1

        new_image_path = "%s/augmented_image_%s.jpg" % (augmented_path, i)

        transformed_image = img_as_ubyte(transformed_image)
        cv2.imwrite(new_image_path, transformed_image)

        i += 1

    except ValueError as e:
        print('could not read the', image, ':', e, 'hence skipping it.')

# %%
# Definisikan path sumber
lung_path = "chest_xray/dataset/"

# Buat daftar yang menyimpan data untuk setiap nama file, path file, dan label dalam data
file_name = []
labels = []
full_path = []

# Dapatkan nama file gambar, path file, dan label satu per satu dengan looping, dan simpan sebagai dataframe
for path, subdirs, files in os.walk(lung_path):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)

distribution_train = pd.DataFrame({"path":full_path, 'file_name':file_name, "labels":labels})

# Plot distribusi gambar di setiap kelas
Label = distribution_train['labels']
plt.figure(figsize = (6,6))
sns.set_style("darkgrid")
plot_data = sns.countplot(Label)

# %%
# Panggil variabel mypath yang menampung folder dataset gambar
mypath= 'chest_xray/dataset/'

file_name = []
labels = []
full_path = []
for path, subdirs, files in os.walk(mypath):
    for name in files:
        full_path.append(os.path.join(path, name))
        labels.append(path.split('/')[-1])
        file_name.append(name)

# Memasukkan variabel yang sudah dikumpulkan pada looping di atas menjadi sebuah dataframe agar rapi
df = pd.DataFrame({"path":full_path,'file_name':file_name,"labels":labels})
# Melihat jumlah data gambar pada masing-masing label
df.groupby(['labels']).size()
# Out:
# labels
# NORMAL       1583
# PNEUMONIA    4273
# dtype: int64

# %%
# Variabel yang digunakan pada pemisahan data ini di mana variabel x = data path dan y = data labels

X= df['path']
y= df['labels']

# Split dataset awal menjadi data train dan test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=300)

# %%
# Menyatukan ke dalam masing-masing dataframe
df_tr = pd.DataFrame({'path':X_train,'labels':y_train,'set':'train'})
df_te = pd.DataFrame({'path':X_test,'labels':y_test,'set':'test'})

# %%
# Gabungkan DataFrame df_tr dan df_te
df_all = pd.concat([df_tr, df_te], ignore_index=True)

print('===================================================== \n')
print(df_all.groupby(['set', 'labels']).size(), '\n')
print('===================================================== \n')

# Cek sampel data
print(df_all.sample(5))

# Memanggil dataset asli yang berisi keseluruhan data gambar yang sesuai dengan labelnya
datasource_path = "chest_xray/dataset/"
# Membuat variabel Dataset, tempat menampung data yang telah dilakukan pembagian data training dan testing
dataset_path = "Dataset-Final/"
# Out:
# =====================================================
#
# set    labels
# test   NORMAL        334
#        PNEUMONIA     838
# train  NORMAL       1249
#        PNEUMONIA    3435
# dtype: int64
#
# =====================================================
#
#                                                    path     labels    set
# 4451  chest_xray/dataset/NORMAL\NORMAL-2926567-0001....     NORMAL  train
# 2915  chest_xray/dataset/PNEUMONIA\VIRUS-8268782-000...  PNEUMONIA  train
# 1903  chest_xray/dataset/PNEUMONIA\VIRUS-37006-0003....  PNEUMONIA  train
# 1229  chest_xray/dataset/PNEUMONIA\BACTERIA-923246-0...  PNEUMONIA  train
# 2096  chest_xray/dataset/PNEUMONIA\BACTERIA-5063219-...  PNEUMONIA  train

# %%
for index, row in tq(df_all.iterrows()):
    # Deteksi filepath
    file_path = row['path']
    if os.path.exists(file_path) == False:
            file_path = os.path.join(datasource_path,row['labels'],row['image'].split('.')[0])

    # Buat direktori tujuan folder
    dest_dir = os.path.join(dataset_path, row['set'], row['labels'])
    os.makedirs(dest_dir, exist_ok=True)

    # Tentukan tujuan file
    destination_file_name = os.path.basename(file_path)
    file_dest = os.path.join(dest_dir, destination_file_name)

    # Salin file dari sumber ke tujuan
    if os.path.exists(file_dest) == False:
        print("SOURCE:", file_path)
        print("DEST:", file_dest)
        shutil.copy2(file_path, file_dest)
# Out:
# 0it [00:00, ?it/s]
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-570144-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-570144-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4176449-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4176449-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5121478-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5121478-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7172433-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7172433-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-990515-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-990515-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6044102-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6044102-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9283703-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9283703-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6526051-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6526051-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-30184-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-30184-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1369326-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1369326-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6168941-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6168941-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8497221-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8497221-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5445939-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5445939-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3258517-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3258517-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7652732-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7652732-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7398200-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7398200-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8983865-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8983865-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4932029-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4932029-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6587932-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6587932-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3003642-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3003642-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8528032-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8528032-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7630183-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7630183-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2801820-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2801820-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6386500-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6386500-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1540910-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1540910-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6592427-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6592427-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8585409-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8585409-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8047963-0007.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8047963-0007.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3038638-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3038638-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9145111-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9145111-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2971615-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2971615-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9156003-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9156003-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4241544-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4241544-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5164118-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5164118-0005.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9000251-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9000251-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8666617-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8666617-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7448311-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7448311-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8645887-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8645887-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-513140-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-513140-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3627124-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3627124-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7828190-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7828190-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3320644-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3320644-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4742760-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4742760-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-267057-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-267057-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8659640-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8659640-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7234183-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7234183-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5202840-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5202840-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3322717-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3322717-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4092125-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4092125-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4127619-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4127619-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8497221-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8497221-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9012339-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9012339-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8738712-0007.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8738712-0007.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8716601-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8716601-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7172433-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7172433-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1514320-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1514320-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2915422-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2915422-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2214391-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-2214391-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7262896-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7262896-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5366209-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5366209-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5098472-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5098472-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9543809-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-9543809-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5555087-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5555087-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5285130-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5285130-0004.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9049547-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9049547-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1591633-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1591633-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3690865-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3690865-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6090737-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6090737-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4623224-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4623224-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9629926-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-9629926-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7022864-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7022864-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5081381-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5081381-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5212251-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5212251-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8241424-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8241424-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9801714-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9801714-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5601980-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5601980-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7430292-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7430292-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2682679-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2682679-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7698004-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7698004-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7849162-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7849162-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7659145-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7659145-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3523856-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3523856-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-724740-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-724740-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5167539-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5167539-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6420973-0008.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6420973-0008.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4603766-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4603766-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8060977-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8060977-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2977655-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2977655-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1820776-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1820776-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5578360-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5578360-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3686746-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3686746-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6500745-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6500745-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4152314-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4152314-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7016792-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7016792-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1884647-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1884647-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5230712-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5230712-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5719837-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5719837-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-71002-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-71002-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8823520-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8823520-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4615614-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4615614-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2474652-0007.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2474652-0007.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8983865-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8983865-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2136769-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2136769-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2617694-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2617694-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3510096-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3510096-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6293151-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6293151-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6394993-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6394993-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1456124-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1456124-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5882940-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5882940-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7834241-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7834241-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8635712-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8635712-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-880930-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-880930-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7103127-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7103127-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1985177-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1985177-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7631316-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7631316-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5423296-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5423296-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7801701-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7801701-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6565531-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6565531-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1538177-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1538177-0006.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8242242-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8242242-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5846441-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5846441-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2111525-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2111525-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2298727-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-2298727-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6410283-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6410283-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3135895-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3135895-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4041959-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4041959-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2727273-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2727273-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9947411-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-9947411-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5882940-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5882940-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1538177-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1538177-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9988673-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9988673-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6340005-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6340005-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9394101-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9394101-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7444876-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7444876-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1314288-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1314288-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4418958-0003.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-4418958-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1440428-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1440428-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-828649-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-828649-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3703049-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3703049-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6590264-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6590264-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5069337-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5069337-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7432256-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7432256-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3371316-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3371316-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5445920-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5445920-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5608291-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5608291-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3590786-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3590786-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7718116-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7718116-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6823523-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6823523-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6473924-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6473924-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7225301-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7225301-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1941403-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1941403-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1191925-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1191925-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5590411-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5590411-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5272604-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5272604-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5748384-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5748384-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2648560-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2648560-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9988673-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9988673-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3399582-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3399582-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5442456-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5442456-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5510638-0008.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5510638-0008.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1958813-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1958813-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4313165-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4313165-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-286376-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-286376-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1855562-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1855562-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6251494-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6251494-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9674936-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9674936-0006.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7001302-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7001302-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7051071-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7051071-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7105903-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7105903-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4462203-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4462203-0004.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-812189-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-812189-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5268966-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5268966-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6950003-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6950003-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7460986-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7460986-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7201196-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7201196-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7942103-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7942103-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5328536-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5328536-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3896855-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3896855-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-669291-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-669291-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4329463-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4329463-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8931850-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8931850-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4177975-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4177975-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3397442-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3397442-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2792838-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2792838-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3971909-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3971909-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5545313-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5545313-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8341352-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8341352-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8837254-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8837254-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-385176-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-385176-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9551241-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-9551241-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5757955-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5757955-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2401713-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2401713-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4394295-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4394295-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1984461-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1984461-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5988773-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5988773-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6249454-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6249454-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3523856-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3523856-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8279635-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8279635-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9422624-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9422624-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7882471-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7882471-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5148117-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5148117-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9400981-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-9400981-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2272663-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2272663-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-390699-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-390699-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5398062-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5398062-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9816293-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9816293-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6105615-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6105615-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6650710-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6650710-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1083680-0021.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1083680-0021.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4617189-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4617189-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-348175-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-348175-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7695736-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7695736-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7721065-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7721065-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9821634-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9821634-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1820776-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1820776-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9176919-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9176919-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-267057-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-267057-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2432050-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-2432050-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-176882-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-176882-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5150733-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5150733-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5510638-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5510638-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-445267-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-445267-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5817596-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5817596-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3105669-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3105669-0005.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4758820-0003.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-4758820-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8748267-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8748267-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5008447-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5008447-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6869947-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6869947-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5476259-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5476259-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5240350-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5240350-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5150733-0013.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5150733-0013.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-447130-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-447130-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2578610-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2578610-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8471954-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8471954-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2792838-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2792838-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1086099-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1086099-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4462203-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4462203-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-215369-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-215369-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-345112-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-345112-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2239132-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-2239132-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3823741-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3823741-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1182905-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1182905-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2968130-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2968130-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-140838-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-140838-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1777631-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1777631-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7051506-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7051506-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7792467-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7792467-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5151909-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5151909-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6802620-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6802620-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6870430-0008.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6870430-0008.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-324273-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-324273-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3246536-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3246536-0005.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5538803-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5538803-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4512-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-4512-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6510775-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6510775-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2190092-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2190092-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8416635-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8416635-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7022864-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7022864-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1984314-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1984314-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3371316-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3371316-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7849162-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7849162-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6275436-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6275436-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1602168-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1602168-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6526933-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6526933-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-463487-0007.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-463487-0007.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2949827-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2949827-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3842946-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3842946-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6085151-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6085151-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9962725-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9962725-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8313724-0003.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8313724-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-869769-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-869769-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8608254-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8608254-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6483321-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6483321-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-355597-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-355597-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2182520-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2182520-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3388576-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3388576-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-705474-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-705474-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3643463-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3643463-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6222402-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6222402-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7338081-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7338081-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7051506-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7051506-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2897609-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2897609-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7620642-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7620642-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6950003-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6950003-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4333878-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4333878-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3781678-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3781678-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9848290-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9848290-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6500745-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6500745-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-696130-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-696130-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9424776-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9424776-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-385176-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-385176-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2402649-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2402649-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9827460-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9827460-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7469623-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7469623-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4323851-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4323851-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6076468-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6076468-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8081717-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8081717-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3644944-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3644944-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8930781-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8930781-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2426822-0008.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2426822-0008.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5155977-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5155977-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5660566-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5660566-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5426353-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5426353-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7103127-0003.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7103127-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8369417-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8369417-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2393203-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2393203-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5123904-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5123904-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6565531-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6565531-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8550709-0010.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8550709-0010.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1768914-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1768914-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-518323-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-518323-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6235826-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6235826-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1984461-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1984461-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7103127-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7103127-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1820776-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1820776-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6376704-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6376704-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6349195-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-6349195-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6461260-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6461260-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3526928-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-3526928-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8451938-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8451938-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6610440-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6610440-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6971619-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6971619-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4747179-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4747179-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-492273-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-492273-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2092977-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2092977-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8995112-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8995112-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8705009-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8705009-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2344316-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2344316-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4892699-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4892699-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8111843-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8111843-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-432590-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-432590-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4401755-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4401755-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7986969-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7986969-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-992913-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-992913-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-86966-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-86966-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3443773-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-3443773-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8660561-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-8660561-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3322717-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3322717-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7953615-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7953615-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3004188-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3004188-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1182905-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1182905-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8426593-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8426593-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1753514-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1753514-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1589680-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1589680-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4059589-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4059589-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9896495-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9896495-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8750763-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-8750763-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5387596-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5387596-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2229606-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2229606-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1753514-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1753514-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8652455-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8652455-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7051506-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7051506-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6642991-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6642991-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2599665-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2599665-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4271267-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4271267-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4320648-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4320648-0004.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1530010-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1530010-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1699306-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1699306-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6062926-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-6062926-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2255274-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-2255274-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9602641-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9602641-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5268802-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-5268802-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1281442-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-1281442-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5661793-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5661793-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5401887-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-5401887-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-1591633-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-1591633-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3042421-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3042421-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2705424-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-2705424-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9142481-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9142481-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7436212-0003.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-7436212-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4811350-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-4811350-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7435285-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7435285-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4615614-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-4615614-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2654345-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2654345-0004.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5425295-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-5425295-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8234246-0002.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-8234246-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2960250-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2960250-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-198200-0007.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-198200-0007.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-338872-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-338872-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-345112-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-345112-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6295192-0005.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-6295192-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2643639-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-2643639-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3348819-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-3348819-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9978536-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-9978536-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9365328-0002.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-9365328-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9250380-0006.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-9250380-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2727335-0003.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-2727335-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1476994-0001.jpeg
# DEST: Dataset-Final/train\NORMAL\NORMAL-1476994-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7721065-0004.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\BACTERIA-7721065-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7295688-0001.jpeg
# DEST: Dataset-Final/train\PNEUMONIA\VIRUS-7295688-0001.jpeg
# ...
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-990412-0009.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8512763-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-8512763-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9363974-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-9363974-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8488185-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8488185-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-556216-0004.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-556216-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5051946-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5051946-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2224169-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-2224169-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5015362-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-5015362-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-191707-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-191707-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4774494-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-4774494-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-564683-0004.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-564683-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7963511-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7963511-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6830488-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-6830488-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7205053-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7205053-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9634181-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-9634181-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-695402-0002.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-695402-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4394900-0005.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4394900-0005.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1177627-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-1177627-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3958628-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-3958628-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6760822-0005.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-6760822-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7193745-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7193745-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8846908-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8846908-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5845895-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-5845895-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7964343-0004.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7964343-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8046863-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8046863-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-104960-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-104960-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3828519-0005.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3828519-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5626093-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5626093-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3443773-0005.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3443773-0005.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3168931-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-3168931-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7175683-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7175683-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6760822-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6760822-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2389446-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-2389446-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6823523-0004.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-6823523-0004.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4853105-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-4853105-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7333515-0002.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7333515-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7801701-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7801701-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8825351-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-8825351-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5428825-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5428825-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6044251-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-6044251-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1083680-0006.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-1083680-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6144452-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-6144452-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3966302-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-3966302-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6443888-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6443888-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5593364-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5593364-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8537791-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8537791-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3975363-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-3975363-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3590786-0010.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-3590786-0010.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3271929-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-3271929-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8111843-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8111843-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8047963-0006.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8047963-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6608539-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6608539-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-4749901-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-4749901-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6003459-0005.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6003459-0005.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9805697-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-9805697-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2828734-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-2828734-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9856874-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-9856874-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6121529-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6121529-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2664973-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-2664973-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4003398-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4003398-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5366209-0004.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5366209-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-3647346-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-3647346-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7696091-0002.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7696091-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9582372-0006.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-9582372-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6472362-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-6472362-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3932811-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3932811-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7922918-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7922918-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7478601-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7478601-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2415177-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-2415177-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5013924-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5013924-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4663193-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-4663193-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6085366-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6085366-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6950003-0004.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6950003-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-752117-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-752117-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3931621-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3931621-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-215369-0007.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-215369-0007.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3865791-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3865791-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4345731-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4345731-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4070745-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4070745-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4199443-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-4199443-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9776714-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-9776714-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8106836-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-8106836-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5100521-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5100521-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3000214-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3000214-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-149498-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-149498-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4647402-0005.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4647402-0005.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-9608945-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-9608945-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-7564600-0007.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-7564600-0007.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-2696292-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-2696292-0003.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-3884102-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-3884102-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4734216-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-4734216-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8652901-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-8652901-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-8451938-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-8451938-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6641294-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-6641294-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-8746767-0002.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-8746767-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7718116-0003.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7718116-0003.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3373762-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-3373762-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5997785-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5997785-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8660561-0010.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8660561-0010.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-202916-0002.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-202916-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-824917-0002.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-824917-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-338181-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-338181-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-412955-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-412955-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-7736073-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-7736073-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-3346259-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-3346259-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8485124-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8485124-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5737325-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5737325-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-4521403-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-4521403-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9115368-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-9115368-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-5889760-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-5889760-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5817596-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5817596-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2339168-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-2339168-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-452131-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-452131-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2897609-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-2897609-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-1453618-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-1453618-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-6268434-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-6268434-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-8166596-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-8166596-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7055226-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7055226-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5715030-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5715030-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-9130179-0004.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-9130179-0004.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4744360-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4744360-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-2034017-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-2034017-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-4956379-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-4956379-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-1241506-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-1241506-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5150733-0006.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5150733-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-5882940-0006.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-5882940-0006.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\VIRUS-5331068-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\VIRUS-5331068-0002.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-6569688-0002.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-6569688-0002.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-2474988-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-2474988-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-6983998-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-6983998-0001.jpeg
# SOURCE: chest_xray/dataset/PNEUMONIA\BACTERIA-9434229-0001.jpeg
# DEST: Dataset-Final/test\PNEUMONIA\BACTERIA-9434229-0001.jpeg
# SOURCE: chest_xray/dataset/NORMAL\NORMAL-7605239-0001.jpeg
# DEST: Dataset-Final/test\NORMAL\NORMAL-7605239-0001.jpeg

# %%
# Definisikan direktori training dan test
TRAIN_DIR = "Dataset-Final/train/"
TEST_DIR = "Dataset-Final/test/"

train_normal = os.path.join(TRAIN_DIR + '/NORMAL')
train_pneumonia = os.path.join(TRAIN_DIR + '/PNEUMONIA')
test_normal = os.path.join(TEST_DIR + '/NORMAL')
test_pneumonia = os.path.join(TEST_DIR + '/PNEUMONIA')

print("Total number of normal images in training set: ",len(os.listdir(train_normal)))
print("Total number of pneumonic images in training set: ",len(os.listdir(train_pneumonia)))
print("Total number of normal images in test set: ",len(os.listdir(test_normal)))
print("Total number of pneumonic images in test set: ",len(os.listdir(test_pneumonia)))
# Out:
# Total number of normal images in training set:  1249
# Total number of pneumonic images in training set:  3435
# Total number of normal images in test set:  334
# Total number of pneumonic images in test set:  838

# %%
# Buat objek ImageDataGenerator yang menormalkan gambar
datagen = ImageDataGenerator(rescale=1/255.,
                                validation_split = 0.2)
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                batch_size=32,
                                                target_size=(150,150),
                                                color_mode="grayscale",
                                                class_mode='binary',
                                                subset='training',
                                                shuffle=True)

validation_generator = datagen.flow_from_directory(TRAIN_DIR,
                                                    batch_size=32,
                                                    target_size=(150,150),
                                                     color_mode="grayscale",
                                                    class_mode='binary',
                                                    subset='validation',
                                                    shuffle=False)

test_generator = test_datagen.flow_from_directory(TEST_DIR,
                                                    batch_size=1,
                                                    target_size=(150,150),
                                                    color_mode="grayscale",
                                                    class_mode='binary',
                                                    shuffle=False)
# Out:
# Found 3748 images belonging to 2 classes.
# Found 936 images belonging to 2 classes.
# Found 1172 images belonging to 2 classes.

# %%
# tf.keras.backend.clear_session()

####################### Init sequential model ##################################
model_1 = Sequential()

# ######################### Input layer with Fully Connected Layer ################################
# 1st Convolutional layer, Batch Normalization layer, and Pooling layer
model_1.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(150,150,1)))
model_1.add(BatchNormalization())
model_1.add(MaxPool2D((2, 2)))

# 2nd Convolutional layer, Batch Normalization layer, and Pooling layer
model_1.add(Conv2D(32, (4, 4),padding='same', activation='relu'))
model_1.add(BatchNormalization())
model_1.add(MaxPool2D((2, 2)))

# 3rd Convolutional layer, Batch Normalization layer, and Pooling layer
model_1.add(Conv2D(32, (7, 7), padding='same', activation='relu'))
model_1.add(BatchNormalization())
model_1.add(MaxPool2D((2, 2)))

# Flatten layer
model_1.add(Flatten())
# 1nd Dense Layer
model_1.add(Dense(128, activation = 'relu'))
# 1nd Dropout Layer
model_1.add(Dropout(0.5))
# 2nd Dense Layer
model_1.add(Dense(64, activation = 'relu'))
# 2nd Dropout Layer
model_1.add(Dropout(0.3))

# Final Dense layer => For output prediction 1 mean (binary class in dataset), sigmoid for binary cases
model_1.add(Dense(1, activation='sigmoid'))
######################### Fully Connected Layer ################################

######################### Compile Model ################################
model_1.compile(optimizer=tf.keras.optimizers.RMSprop(),
                loss='binary_crossentropy',
                metrics=['accuracy'])

# Summary of the Model Architecture
print(model_1.summary())
# Out:
# c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 32)     │        16,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 75, 75, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 37, 37, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 37, 37, 32)     │        50,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 37, 37, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 18, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10368)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,327,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,402,881 (5.35 MB)
#  Trainable params: 1,402,689 (5.35 MB)
#  Non-trainable params: 192 (768.00 B)
# None

# %%
count_normal, count_pneumonia = len(os.listdir(train_normal)), len(os.listdir(train_pneumonia))
weight_0 = (1 / count_normal) * (count_normal + count_pneumonia) / 2.0
weight_1 = (1 / count_pneumonia) * (count_pneumonia + count_normal) / 2.0

class_weights = {0 : weight_0, 1 : weight_1}

# %time

# Fitting / training model
history_1 = model_1.fit(train_generator,
                        epochs=30,
                        batch_size=32,
                        validation_data=validation_generator,
                        class_weight = class_weights)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Epoch 1/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 218s 2s/step - accuracy: 0.8247 - loss: 0.9740 - val_accuracy: 0.7340 - val_loss: 5.8865
# Epoch 2/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 108s 917ms/step - accuracy: 0.9120 - loss: 0.3486 - val_accuracy: 0.7340 - val_loss: 20.0931
# Epoch 3/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 105s 890ms/step - accuracy: 0.9242 - loss: 0.2661 - val_accuracy: 0.7340 - val_loss: 30.0081
# Epoch 4/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 106s 899ms/step - accuracy: 0.9298 - loss: 0.2495 - val_accuracy: 0.8088 - val_loss: 0.5829
# Epoch 5/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 105s 889ms/step - accuracy: 0.9466 - loss: 0.2111 - val_accuracy: 0.7511 - val_loss: 3.6328
# Epoch 6/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 108s 909ms/step - accuracy: 0.9509 - loss: 0.1996 - val_accuracy: 0.7169 - val_loss: 0.5321
# Epoch 7/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 112s 954ms/step - accuracy: 0.9554 - loss: 0.1451 - val_accuracy: 0.9423 - val_loss: 0.2688
# Epoch 8/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 109s 921ms/step - accuracy: 0.9536 - loss: 0.1340 - val_accuracy: 0.9113 - val_loss: 0.9895
# Epoch 9/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 106s 894ms/step - accuracy: 0.9546 - loss: 0.1363 - val_accuracy: 0.9605 - val_loss: 0.2579
# Epoch 10/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 105s 886ms/step - accuracy: 0.9608 - loss: 0.1192 - val_accuracy: 0.9701 - val_loss: 0.2883
# Epoch 11/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 106s 901ms/step - accuracy: 0.9656 - loss: 0.0956 - val_accuracy: 0.9519 - val_loss: 0.5610
# Epoch 12/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 140s 884ms/step - accuracy: 0.9616 - loss: 0.1284 - val_accuracy: 0.9690 - val_loss: 0.2657
# Epoch 13/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 105s 891ms/step - accuracy: 0.9691 - loss: 0.1013 - val_accuracy: 0.8985 - val_loss: 2.5689
# Epoch 14/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 101s 857ms/step - accuracy: 0.9728 - loss: 0.0838 - val_accuracy: 0.8344 - val_loss: 0.4430
# Epoch 15/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 100s 843ms/step - accuracy: 0.9760 - loss: 0.0724 - val_accuracy: 0.8323 - val_loss: 0.4557
# Epoch 16/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 96s 814ms/step - accuracy: 0.9768 - loss: 0.0660 - val_accuracy: 0.9551 - val_loss: 0.2729
# Epoch 17/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 96s 817ms/step - accuracy: 0.9779 - loss: 0.0783 - val_accuracy: 0.9541 - val_loss: 0.5806
# Epoch 18/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 96s 817ms/step - accuracy: 0.9781 - loss: 0.0770 - val_accuracy: 0.9690 - val_loss: 0.2745
# Epoch 19/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 818ms/step - accuracy: 0.9789 - loss: 0.0670 - val_accuracy: 0.9583 - val_loss: 0.2621
# Epoch 20/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 819ms/step - accuracy: 0.9832 - loss: 0.0566 - val_accuracy: 0.9573 - val_loss: 0.6294
# Epoch 21/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 96s 814ms/step - accuracy: 0.9835 - loss: 0.0530 - val_accuracy: 0.9509 - val_loss: 0.3501
# Epoch 22/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 821ms/step - accuracy: 0.9867 - loss: 0.0369 - val_accuracy: 0.9487 - val_loss: 0.2535
# Epoch 23/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 822ms/step - accuracy: 0.9888 - loss: 0.0340 - val_accuracy: 0.9701 - val_loss: 0.4023
# Epoch 24/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 818ms/step - accuracy: 0.9912 - loss: 0.0262 - val_accuracy: 0.8323 - val_loss: 4.7961
# Epoch 25/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 98s 828ms/step - accuracy: 0.9931 - loss: 0.0277 - val_accuracy: 0.9583 - val_loss: 0.5443
# Epoch 26/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 819ms/step - accuracy: 0.9888 - loss: 0.0454 - val_accuracy: 0.9647 - val_loss: 0.3657
# Epoch 27/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 98s 826ms/step - accuracy: 0.9925 - loss: 0.0315 - val_accuracy: 0.9530 - val_loss: 0.4364
# Epoch 28/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 825ms/step - accuracy: 0.9912 - loss: 0.0271 - val_accuracy: 0.9626 - val_loss: 0.3127
# Epoch 29/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 819ms/step - accuracy: 0.9931 - loss: 0.0225 - val_accuracy: 0.9658 - val_loss: 0.3027
# Epoch 30/30
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 97s 822ms/step - accuracy: 0.9944 - loss: 0.0164 - val_accuracy: 0.9605 - val_loss: 0.3117

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']
loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('Training and Validaion Loss')
plt.show()

# %%
test_generator.reset()

preds_1 = model_1.predict(test_generator,verbose=0)
preds_1 = preds_1.copy()
preds_1[preds_1 <= 0.5] = 0
preds_1[preds_1 > 0.5] = 1

# Print Confusion Matrix
cm = pd.DataFrame(data=confusion_matrix(test_generator.classes, preds_1, labels=[0, 1]),index=["Actual Normal", "Actual Pneumonia"],
columns=["Predicted Normal", "Predicted Pneumonia"])
sns.heatmap(cm,annot=True,fmt="d")

# Print Classification Report
print("\n")
print(classification_report(y_true=test_generator.classes,y_pred=preds_1,target_names =['Normal','Pneumonia'], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#       Normal     0.8967    0.9880    0.9402       334
#    Pneumonia     0.9950    0.9547    0.9744       838
#
#     accuracy                         0.9642      1172
#    macro avg     0.9459    0.9713    0.9573      1172
# weighted avg     0.9670    0.9642    0.9647      1172
